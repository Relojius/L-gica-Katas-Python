# %%
# 15. Crea una función lambda que sume 3 a cada número de una lista dada.
sumar_tres = lambda numeros: list(map(lambda x: x + 3, numeros))

# Ejemplo de uso:
lista = [1, 5, 10]
print(sumar_tres(lista))
# Out:
# [4, 8, 13]
