# %%
# 21. Crea una función que calcule el cubo de un número dado mediante una función lambda
cubo = lambda x: x**3

numero = float(input("Introduce un número: "))
resultado = cubo(numero)

print("El cubo es:", resultado)
# Out:
# El cubo es: 64.0
