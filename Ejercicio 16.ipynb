# %%
# 16. Escribe una función que tome una cadena de texto y un número entero n como parámetros y devuelva una lista de
# todas las palabras que sean más largas que n. Usa la función filter()
def palabras_mas_largas(cadena, n):
    palabras = cadena.split()  # Convertimos la cadena en lista de palabras
    return list(filter(lambda p: len(p) > n, palabras))


# Ejemplo de uso:
texto = "Este es un ejemplo sencillo para probar la función"
print(palabras_mas_largas(texto, 4))
# Out:
# ['ejemplo', 'sencillo', 'probar', 'función']
