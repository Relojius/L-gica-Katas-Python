# %%
# 19. Crea una función lambda que filtre los números impares de una lista dada.
impares = lambda numeros: list(filter(lambda x: x % 2 != 0, numeros))

# Ejemplo de uso:
lista = [1, 2, 3, 4, 5, 6, 7]
print(impares(lista))
# Out:
# [1, 3, 5, 7]
